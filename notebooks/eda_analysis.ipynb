# %%
# eda_analysis.ipynb

import os
import sys

# Ensure the script's directory is in the path
sys.path.append('../scripts')

from combined_eda import perform_eda

file_path = 'C:/Users/user/Desktop/Github/NovaFinancialSolutions-/scripts/raw_analyst_ratings.csv'
results = perform_eda(file_path)

print(results)
# Out:
# Dataset loaded successfully.
# Date column preprocessed successfully.
# Headline Length Statistics:
#  count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64
# Articles per Publisher:
#  publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# Matthew Ely               1
# Frank Ochoa               1
# Jeremie Capron            1
# Marvin Dumont             1
# Igor Gonta                1
# Name: count, Length: 1034, dtype: int64
# Publication Date Trends:
#  date
# 2009-02-14      1
# 2009-04-27      2
# 2009-04-29      1
# 2009-05-22      1
# 2009-05-27      6
#              ...
# 2020-06-07     25
# 2020-06-08    765
# 2020-06-09    804
# 2020-06-10    806
# 2020-06-11    544
# ...
